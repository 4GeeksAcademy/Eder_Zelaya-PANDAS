# %% [markdown]
# # Limpieza del dataset de bienes raíces
#
# Este es un conjunto de datos (dataset) reales que fue descargado usando técnicas de web scraping. El archivo contiene registros de **Fotocasa**, el cual es uno de los sitios más populares de bienes raíces en España. Contiene miles de datos de casas reales publicadas en la web www.fotocasa.com.
#
# El dataset fue descargado hace algunos años y en ningún caso se obtuvo beneficio económico de ello.
#
# Tu objetivo es extraer tanta información como sea posible con el conocimiento que tienes hasta ahora de ciencia de datos.
#
# Agrega observaciones, conclusiones o notas acerca de los datos obtenidos en cada ejercicio.

# %%
import pandas as pd

# %% [markdown]
# #### Ejercicio 00
#
# Lee el dataset data/real_estate.csv e intenta visualizar la tabla (★☆☆)

# %%
# Este archivo CSV contiene puntos y comas en lugar de comas como separadores
df = pd.read_csv('real_estate.csv', sep=';')
df
# Out:
#        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...           ...             ...    ...                                ...
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15332       15333       153901397  False             tecnocasa torrelodones
# 15333       15334       152607440  False                inmobiliaria pulpon
# 15334       15335       153901356  False                infocasa consulting
#
#        phone_realEstate                                       url_inmueble  \
# 0           912177526.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 1           916358736.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 2           916350408.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 3           916358736.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 4           912177526.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# ...                 ...                                                ...
# 15330       911360461.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 15331       912788039.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 15332       912780348.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 15333       912788039.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 15334       911360461.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
#
#        rooms  bathrooms  surface   price  ... level4Id level5Id level6Id  \
# 0        3.0        2.0    103.0  195000  ...        0        0        0
# 1        3.0        1.0      NaN   89000  ...        0        0        0
# 2        2.0        2.0     99.0  390000  ...        0        0        0
# 3        3.0        1.0     86.0   89000  ...        0        0        0
# 4        2.0        2.0    106.0  172000  ...        0        0        0
# ...      ...        ...      ...     ...  ...      ...      ...      ...
# 15330    2.0        1.0     96.0  259470  ...        0        0        0
# 15331    3.0        1.0    150.0  165000  ...        0        0        0
# 15332    4.0        2.0    175.0  495000  ...        0        0        0
# 15333    3.0        2.0    101.0  195000  ...        0        0        0
# 15334    3.0        2.0    152.0  765000  ...        0        0        0
#
#       level7Id level8Id accuracy          latitude          longitude zipCode  \
# 0            0        0        0  40,2948276786438  -3,44402412135624     NaN
# 1            0        0        1          40,28674           -3,79351     NaN
# 2            0        0        0  40,4115646786438  -3,90662252135624     NaN
# 3            0        0        0  40,2853785786438  -3,79508142135624     NaN
# 4            0        0        0  40,2998774864376  -3,45226301356237     NaN
# ...        ...      ...      ...               ...                ...     ...
# 15330        0        0        0          40,45416           -3,70286     NaN
# 15331        0        0        0          40,36652           -3,48951     NaN
# 15332        0        0        0          40,57444           -3,92124     NaN
# 15333        0        0        0          40,36967           -3,48105     NaN
# 15334        0        0        0          40,45773           -3,69068     NaN
#
#       customZone
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 15330        NaN
# 15331        NaN
# 15332        NaN
# 15333        NaN
# 15334        NaN
#
# [15335 rows x 37 columns]

# %%
casa_mas_cara = df.loc[df['price'].idxmax()]
direccion = casa_mas_cara['address']
precio = casa_mas_cara['price']

print(f"La casa más cara está en: {direccion} y su precio es {precio}")
# Out:
# La casa más cara está en: El Escorial y su precio es 8500000

# %% [markdown]
# #### Ejercicio 02
#
# ¿Cuál es la casa más barata del dataset? (★☆☆)
#
# Imprime la dirección y el precio de la casa seleccionada utilizando f-string

# %%
casa_mas_barata = df.loc[df['price']>0]['price'].idxmin()
direccion = df.loc[casa_mas_barata, "address"]
precio = df.loc[casa_mas_barata, 'price']

print(f"La casa más barata está en: {direccion} y su precio es {precio}")
# Out:
# La casa más barata está en: Berlin, Coslada y su precio es 600

# %% [markdown]
# #### Ejercicio 03
#
# ¿Cuál es la casa más grande del dataset? (★☆☆)
#
# Imprime la dirección y el área de las casas seleccionadas utilizando f-string

# %%
casa_mas_grande = df.loc[df['surface'].idxmax()]
direccion = casa_mas_grande['address']
area = casa_mas_grande['surface']

print(f"La casa más grande está en: {direccion} y su tamaño es {area} metros cuadrados")
# Out:
# La casa más grande está en: Sevilla la Nueva y su tamaño es 249000.0 metros cuadrados

# %% [markdown]
# #### Ejercicio 04
#
# ¿Cuál es la casa más pequeña del dataset? (★☆☆)

# %%
casa_mas_pequeña = df.loc[df['surface'].idxmin()]
direccion = casa_mas_pequeña['address']
area = casa_mas_pequeña['surface']

print(f"La casa más pequeña está en: {direccion} y su tamaño es {area} metros cuadrados")
# Out:
# La casa más pequeña está en: Calle Amparo,  Madrid Capital y su tamaño es 15.0 metros cuadrados

# %% [markdown]
# #### Ejercicio 05.
#
# ¿El dataset contiene valores no admitidos (NAs)? (★☆☆)
#
# - Muestra el nombre de las filas seguidas por un booleano (`True` o `False`) según contengan o no contengan NAs.
# - También muestra el nombre de las columnas seguidas por un booleano (`True` o `False`) según contengan o no contengan NAs.

# %%
filas_con_nas = df.isna().any(axis=1)
columnas_con_nas = df.isna().any()

print("Filas con NAs:")
print(filas_con_nas)

print("\nColumnas con NAs:")
print(columnas_con_nas)
# Out:
# Filas con NAs:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 15330    True
# 15331    True
# 15332    True
# 15333    True
# 15334    True
# Length: 15335, dtype: bool
#
# Columnas con NAs:
# Unnamed: 0          False
# id_realEstates      False
# isNew               False
# realEstate_name      True
# phone_realEstate     True
# url_inmueble        False
# rooms                True
# bathrooms            True
# surface              True
# price               False
# date                False
# description          True
# address             False
# country             False
# level1              False
# level2              False
# level3              False
# level4               True
# level5              False
# level6               True
# level7               True
# level8               True
# upperLevel          False
# countryId           False
# level1Id            False
# level2Id            False
# level3Id            False
# level4Id            False
# level5Id            False
# level6Id            False
# level7Id            False
# level8Id            False
# accuracy            False
# latitude            False
# longitude           False
# zipCode              True
# customZone           True
# dtype: bool

# %% [markdown]
# #### Ejercicio 06.
#
# Elimina las columnas que contengan NAs del dataset, si aplica (★★☆)
#
# Muestra las dimensiones del DataFrame original y del DataFrame después de las eliminaciones.

# %%
df.shape # El Data frame sin NAs contiene 5269 filas y 37 columnas
eliminaciones_df = df.dropna(axis=1)

f'DataFrame original: {df.shape[1]} columnas, DataFrame con columnas eliminadas: {eliminaciones_df.shape[1]}'
# Out:
# 'DataFrame original: 37 columnas, DataFrame con columnas eliminadas: 25'

# %% [markdown]
# #### Ejercicio 07
#
# ¿Cuantas poblaciones (columna level5) contiene el dataset? (★☆☆)
#
# - Muestra una lista con los nombres de las poblaciones
# - Muestra el total de las mismas

# %%
poblaciones = df['level5'].unique()

print(poblaciones)

total_poblaciones = df["level5"].nunique()

print("\nTotal numero de poblaiociones:", total_poblaciones)
# Out:
# ['Arganda del Rey' 'Fuenlabrada' 'Boadilla del Monte'
#  'Las Rozas de Madrid' ' Madrid Capital' 'Villaviciosa de Odón' 'Pinto'
#  'Valdemoro' 'Navalcarnero' 'Pozuelo de Alarcón' 'Torrejón de Ardoz'
#  'Navalagamella' 'San Sebastián de los Reyes' 'Rivas-vaciamadrid'
#  'Alpedrete' 'Móstoles' 'San Fernando de Henares' 'Coslada'
#  'Becerril de la Sierra' 'Alcalá de Henares' 'Chinchón' 'Parla' 'Alcorcón'
#  'El Escorial' 'Leganés' 'Pedrezuela' 'Majadahonda'
#  'Villanueva de la Cañada' 'Villanueva del Pardillo' 'Torrelodones'
#  'Moralzarzal' 'Mejorada del Campo' 'Aranjuez' 'Corpa' 'Getafe'
#  'Velilla de San Antonio' 'Sevilla la Nueva' 'San Martín de la Vega'
#  'Villalbilla' 'Collado Villalba' 'Alcobendas' 'El Molar (Madrid)'
#  'Moraleja de Enmedio' 'Algete' 'Campo Real' 'Torrejón de la Calzada'
#  'Colmenar Viejo' 'Valdemorillo' 'Fuente El Saz de Jarama' 'Tres Cantos'
#  'Arroyomolinos (Madrid)' 'Griñón' 'Paracuellos de Jarama' 'Guadarrama'
#  'Titulcia' 'Galapagar' 'Collado Mediano' 'Los Molinos'
#  'San Lorenzo de El Escorial' 'Loeches' 'San Martín de Valdeiglesias'
#  'Navas del Rey' 'Bustarviejo' 'Manzanares El Real' 'Carabaña'
#  'Casarrubuelos' 'Cercedilla' 'Fresnedillas de la Oliva' 'Valdemaqueda'
#  'Robledo de Chavela' 'Miraflores de la Sierra' 'Humanes de Madrid'
#  'Valdetorres de Jarama' 'San Agustín del Guadalix' 'Ciempozuelos'
#  'Camarma de Esteruelas' 'Torres de la Alameda' 'Talamanca de Jarama'
#  'El Atazar' 'Hoyo de Manzanares' 'El Boalo - Cerceda – Mataelpino'
#  'El Álamo' 'Valdilecha' 'Valdeolmos-Alalpardo' 'Guadalix de la Sierra'
#  'Belmonte de Tajo' 'El Vellón' 'Brunete' 'Redueña' 'Morata de Tajuña'
#  'Tielmes' 'Gargantilla del Lozoya' 'Meco' 'Venturada' 'Quijorna'
#  'Cenicientos' 'Torrejón de Velasco' 'Navacerrada'
#  'Santa María de la Alameda' 'Orusco de Tajuña' 'Daganzo de Arriba'
#  'Villamanta' 'Anchuelo' 'Valdaracete' 'Ajalvir' 'Los Santos de la Humosa'
#  'Villamanrique de Tajo' 'Colmenar de Oreja' 'Villa del Prado'
#  'Fuentidueña de Tajo' 'Colmenar del Arroyo' 'Valdelaguna'
#  'Cubas de la Sagra' 'Valdeavero' 'Aldea del Fresno' 'Ribatejada'
#  'Torrelaguna' 'Batres' 'Pezuela de las Torres' 'Colmenarejo'
#  'Serranillos del Valle' 'Cobeña' 'Soto del Real' 'El Berrueco'
#  'Villanueva de Perales' 'Fresno de Torote - Serracines' 'Pozuelo del Rey'
#  'Pelayos de la Presa' 'La Cabrera' 'Nuevo Baztán' 'Perales de Tajuña'
#  'Villaconejos' 'Villarejo de Salvanés' 'Cadalso de los Vidrios'
#  'Santorcaz' 'Madarcos' 'Garganta de los Montes' 'Puentes Viejas'
#  'Torremocha de Jarama' 'Valdemanco' 'Braojos'
#  'Lozoyuela-navas-sieteiglesias' 'Piñuécar-gandullas' 'Valdepiélagos'
#  'Valverde de Alcalá' 'Villar del Olmo' 'Villamantilla'
#  'Horcajo de la Sierra' 'Gascones' 'Zarzalejo' 'Villavieja del Lozoya'
#  'Brea de Tajo' 'Estremera' 'Chapinería' 'Navarredonda' 'Patones' 'Ambite'
#  'Navalafuente' 'Lozoya' 'Canencia' 'Cabanillas de la Sierra'
#  'Buitrago del Lozoya' 'Fresno de Torote' 'Robregordo' 'Pinilla del Valle'
#  'Rascafría' 'La Hiruela' 'Montejo de la Sierra']
#
# Total numero de poblaiociones: 168

# %% [markdown]
# #### Ejercicio 08
#
# ¿Cuál es la media de precios en la población (columna level5) de "Arroyomolinos (Madrid)"? (★★☆)

# %%
Precio_poblacion = df.loc[df['level5'] == 'Arroyomolinos (Madrid)']['price'].mean()
print(f"La media de precios en Arroyomolinos (Madrid) es: {int(Precio_poblacion)} €")
# Out:
# La media de precios en Arroyomolinos (Madrid) es: 294541 €

# %% [markdown]
# #### Ejercicio 09.
#
# ¿Los precios promedios de "Valdemorillo" y "Galapagar" son iguales? (★★☆)
#
# - Muestra ambos promedios
# - Escribe en una celda markdown una conclusión sobre ellos

# %%
Promedio_valdemorillo = df.loc[df['level5'] == 'Valdemorillo']['price'].mean()

Promedio_galapagar = df.loc[df['level5'] == 'Galapagar']['price'].mean()


print(f"Promedio de Valdemorillo: {int(Promedio_valdemorillo)} €")
print(f"Precio de Galapagar: {int(Promedio_galapagar)} €")
# Out:
# Promedio de Valdemorillo: 363860 €
# Precio de Galapagar: 360063 €

# %% [markdown]
# Los precios promedios de Valdemorillo 363,860.29 € y Galapagar 360,063.20 €
# son muy similares, con diferencia de 3,797.09 €
#
# Ambas localidades comparten un mercado inmobiliario con características y valoraciones muy parecidas, situándose en un rango de precio similar

# %% [markdown]
# #### Ejercicio 10
#
# ¿Los promedios de precio por metro cuadrado (precio/m2) de "Valdemorillo" y "Galapagar" son iguales? (★★☆)
#
# > Pista: Crea una nueva columna llamada `pps` (*price per square* o precio por metro cuadrado) y luego analiza los valores.
#
# - Muestra ambos promedios de precio por metro cuadrado
# - Escribe en una celda markdown una conclusión sobre ellos

# %%
df["pps"]=df["price"]/df["surface"]
media_de_precios_por_mts2 = df.groupby("level5")["pps"].mean()
precios_valdemorillo_por_mts2 = int(media_de_precios_por_mts2["Valdemorillo"])
precios_galapagar_por_mts2 = int(media_de_precios_por_mts2["Galapagar"])
f"precios promedio en Valdemorillo por metros2: {precios_valdemorillo_por_mts2} precios promedio en Galapagar por metros2: {precios_galapagar_por_mts2}"
# Out:
# 'precios promedio en Valdemorillo por metros2: 1317 precios promedio en Galapagar por metros2: 1606'

# %% [markdown]
# #### Ejercicio 11
#
# ¿Cuántas agencia de bienes raíces contiene el dataset? (★★☆)
#
# - Muestra el valor obtenido.

# %%
lista_de_inmoviliarias = df["realEstate_name"].unique()
df["realEstate_name"].nunique()
# Out:
# 1821

# %% [markdown]
# #### Ejercicio 12
#
# ¿Cuál es la población (columna level5) que contiene la mayor cantidad de casas?(★★☆)
#
# - Muestra la población y el número de casas.

# %%
casas_por_poblacion = df["level5"].value_counts() # nos  indica el numeros de casas por poblaciones
casas_por_poblacion.idxmax(), int(casas_por_poblacion.max())    #idxmax retuna la poblacion del numero maximo, y max el numero maximo
# Out:
# (' Madrid Capital', 6643)

# %% [markdown]
# ---
#
# ## Trabajando con un subconjunto del DataFrame

# %% [markdown]
# #### Ejercicio 13
#
# Ahora vamos a trabajar con el "cinturón sur" de Madrid.
#
# Haz un subconjunto del DataFrame original que contenga las siguientes poblaciones (columna level5): "Fuenlabrada", "Leganés", "Getafe", "Alcorcón" (★★☆)
#
# > Pista: Filtra el DataFrame original usando la columna `level5` y la función `isin`.

# %%
df_sub = df[df["level5"].isin(["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"])]
df_sub
# Out:
#        Unnamed: 0  id_realEstates  isNew  \
# 1               2       153867863  False
# 3               4       152776331  False
# 85             86       153152077  False
# 94             95       153995577  False
# 109           110       153586414  False
# ...           ...             ...    ...
# 15275       15276       153903887  False
# 15291       15292       151697757  False
# 15305       15306       153902389  False
# 15322       15323       153871864  False
# 15325       15326       153901467  False
#
#                                  realEstate_name  phone_realEstate  \
# 1              tecnocasa fuenlabrada ferrocarril       916358736.0
# 3              tecnocasa fuenlabrada ferrocarril       916358736.0
# 85                       sinergical inmobiliaria               NaN
# 94                               viviendas365com       911226014.0
# 109              area uno asesores inmobiliarios       912664081.0
# ...                                          ...               ...
# 15275  aliseda servicios de gestion inmobiliaria       911368198.0
# 15291                                    unipiso       912788631.0
# 15305                             jadein ferrero       914871639.0
# 15322                          gestion comercial       911220662.0
# 15325                              montehogar 68       911790675.0
#
#                                             url_inmueble  rooms  bathrooms  \
# 1      https://www.fotocasa.es/es/comprar/vivienda/ma...    3.0        1.0
# 3      https://www.fotocasa.es/es/comprar/vivienda/ma...    3.0        1.0
# 85     https://www.fotocasa.es/es/comprar/vivienda/le...    1.0        1.0
# 94     https://www.fotocasa.es/es/comprar/vivienda/le...    3.0        2.0
# 109    https://www.fotocasa.es/es/comprar/vivienda/ma...    3.0        3.0
# ...                                                  ...    ...        ...
# 15275  https://www.fotocasa.es/es/comprar/vivienda/al...    3.0        1.0
# 15291  https://www.fotocasa.es/es/comprar/vivienda/al...    3.0        2.0
# 15305  https://www.fotocasa.es/es/comprar/vivienda/ma...    3.0        2.0
# 15322  https://www.fotocasa.es/es/comprar/vivienda/ma...    3.0        1.0
# 15325  https://www.fotocasa.es/es/comprar/vivienda/ma...    2.0        2.0
#
#        surface   price  ... level5Id level6Id level7Id level8Id accuracy  \
# 1          NaN   89000  ...        0        0        0        0        1
# 3         86.0   89000  ...        0        0        0        0        0
# 85        50.0  107000  ...        0        0        0        0        1
# 94       120.0  320000  ...        0        0        0        0        0
# 109      142.0  425000  ...        0        0        0        0        0
# ...        ...     ...  ...      ...      ...      ...      ...      ...
# 15275     78.0  138000  ...        0        0        0        0        1
# 15291    110.0  279000  ...        0        0        0        0        0
# 15305     85.0  170000  ...        0        0        0        0        0
# 15322     91.0  112000  ...        0        0        0        0        0
# 15325     99.0  215000  ...        0        0        0        0        1
#
#                latitude          longitude zipCode customZone          pps
# 1              40,28674           -3,79351     NaN        NaN          NaN
# 3      40,2853785786438  -3,79508142135624     NaN        NaN  1034.883721
# 85             40,35059           -3,82693     NaN        NaN  2140.000000
# 94             40,31933           -3,77574     NaN        NaN  2666.666667
# 109          40,3313411         -3,8313868     NaN        NaN  2992.957746
# ...                 ...                ...     ...        ...          ...
# 15275          40,31381           -3,83733     NaN        NaN  1769.230769
# 15291        40,3259051           -3,76318     NaN        NaN  2536.363636
# 15305        40,2882193         -3,8098617     NaN        NaN  2000.000000
# 15322          40,28282           -3,78892     NaN        NaN  1230.769231
# 15325          40,28062           -3,79869     NaN        NaN  2171.717172
#
# [907 rows x 38 columns]

# %% [markdown]
# #### Ejercicio 14
#
# Calcula la media y la varianza de muestra para las siguientes variables: precio, habitaciones, superficie y baños (★★★)
#
# > Debes usar el subset obtenido en la pregunta 13
#
# - Crea y visualiza un diccionario con todos los valores

# %%
medias = df_sub.groupby("level5")[["bathrooms","surface","rooms", "price"]].mean()
varianzas = df_sub.groupby("level5")[["bathrooms","surface","rooms", "price"]].var()
poblaciones = {}
for poblacion in df_sub["level5"].unique():
  poblaciones[poblacion] ={}
for poblacion in poblaciones.keys():
  for column in varianzas:
    poblaciones[poblacion][column+"_var"] = round(float(varianzas.loc[poblacion, column]),2)
  for column in medias:
    poblaciones[poblacion][column+"_mean"] = round(float(medias.loc[poblacion, column]),2)
poblaciones
# Out:
# {'Fuenlabrada': {'bathrooms_var': 0.35,
#   'surface_var': 2264.64,
#   'rooms_var': 0.36,
#   'price_var': 4701020700.47,
#   'bathrooms_mean': 1.45,
#   'surface_mean': 103.62,
#   'rooms_mean': 3.03,
#   'price_mean': 177198.02},
#  'Alcorcón': {'bathrooms_var': 0.59,
#   'surface_var': 4244.32,
#   'rooms_var': 0.93,
#   'price_var': 15947825983.01,
#   'bathrooms_mean': 1.62,
#   'surface_mean': 105.91,
#   'rooms_mean': 2.91,
#   'price_mean': 230071.05},
#  'Leganés': {'bathrooms_var': 0.55,
#   'surface_var': 3987.48,
#   'rooms_var': 0.82,
#   'price_var': 11913940043.5,
#   'bathrooms_mean': 1.52,
#   'surface_mean': 105.85,
#   'rooms_mean': 2.91,
#   'price_mean': 208682.01},
#  'Getafe': {'bathrooms_var': 0.66,
#   'surface_var': 5828.11,
#   'rooms_var': 0.77,
#   'price_var': 20982665802.24,
#   'bathrooms_mean': 1.87,
#   'surface_mean': 126.9,
#   'rooms_mean': 3.15,
#   'price_mean': 265040.5}}

# %% [markdown]
# #### Ejercicio 15
#
# ¿Cuál es la casa más cara de cada población del cinturón sur de Madríd? (★★☆)
#
# > Debes usar el subset obtenido en la pregunta 13
#
# - Genera un DataFrame con esta información
# - Muestra tanto la dirección como el precio de la casa seleccionada de cada población.
# - Genera conclusiones en una celda markdown

# %%
precios_max = df_sub.loc[df_sub.groupby("level5")["price"].idxmax(),["level5","address","price"]]
precios_max
# Out:
#             level5                                address    price
# 5585      Alcorcón                               Alcorcón   950000
# 11561  Fuenlabrada  Calle de Paulo Freire, 5, Fuenlabrada   490000
# 2881        Getafe                                 Getafe  1050000
# 10412      Leganés           Avenida Reina Sofía, Leganés   650000

# %% [markdown]
# #### Ejercicio 16
#
# ¿Qué puedes decir acerca del precio por metro cuadrado (precio/m2) entre los municipios de 'Getafe' y 'Alcorcón'? (★★☆)
#
# > Debes usar el subset obtenido en la pregunta 13
# >
# > Pista: Crea una nueva columna llamada `pps` (price per square en inglés) y luego analiza los valores

# %%
media_de_precios_por_mts2 = df_sub.groupby("level5")["pps"].mean()
media_de_precios_por_mts2
precios_promedio_en_getafe = int(media_de_precios_por_mts2["Getafe"])
precios_promedio_en_alcorcon = int(media_de_precios_por_mts2["Alcorcón"])
print(f"precios promedio en Getafe por metros2: {precios_promedio_en_getafe}\n precios promedio en Alcorcon por metros2: {precios_promedio_en_alcorcon}")
# Out:
# precios promedio en Getafe por metros2: 2066
#  precios promedio en Alcorcon por metros2: 2239

# %% [markdown]
# ## Conclusiones

# %% [markdown]
# #### Ejercicio 17
#
# Escribe aquí tus conclusiones acerca de este proyecto

# %% [markdown]
# En el conjunto de datos analizado.
#
# El valor de las viviendas está significativamente influenciado por su localización geográfica, lo que se refleja en los promedios de precios por zona en relación con la superficie habitable.
# Una propiedad de menores dimensiones ubicada en una área de alto valor inmobiliario puede alcanzar un precio superior al de una vivienda más amplia situada en una zona más económica.
